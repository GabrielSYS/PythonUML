# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielSYS/PythonUML/blob/main/HorarioMedica%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esse é um trabalho de UML e Python em desenvolvimento

# %%
from PIL import Image

imagem = Image.open('programacao_remedio.png')

imagem.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=754x522 at 0x7F3DDF5F0CA0>

# %%
class HorarioMedicacao:
    ''' Classe que avisa os horarios pré-determinados para para ingestão de medicamento'''

    def __init__(self, nome_pct, nome_medicamento, dosagem, vezes_dia):
        self.ficha_paciente = []


    def ficha_pacientelistaMedicamento(self, nome_pct, nome_medicamento, dosagem, vezes_dia):
        self.nome_pct = nome_pct
        self.nome_medicamento = nome_medicamento
        self.dosagem = dosagem
        self.vezes_dia = vezes_dia


    ficha_pacientelistaMedicamento = dados_paciente()

     listaMedicamento = [
        {'medicamento': 'buscopão', 'horario': 12, 'dosagem': 1},
        {'medicamento': 'benegri-pi', 'horario': 10, 'dosagem': 50},
        {'medicamento': 'gelou', 'horario': 8, 'dosagem': 15}
    ]


class dados_paciente:
  '''Classe para cadastro de dados do paciente'''
    def paciente(self)
      self.nome_pct = str(input("Nome do paciente: "))
      self.nome_medicamento = str(input("Nome do medicamento: "))
      self.dosagem = str(input("dosagem prescrita pelo médico: "))
      self.vezes_dia = int(input("quantas vezes ao dia: "))

    @staticmethod
    def buscar():
      busca_medicamento = nome_medicamento

    @staticmethod
    def buscar():
        busca_medicamento = horario_medicacao.lista_medicamento[0]['nome_medicamento']
        return busca_medicamento
